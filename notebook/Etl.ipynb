# %%
import os
import sys
import logging

import pandas as pd
import numpy as np

# %%
#----------------------------------------------------------------
# Configurations section
#----------------------------------------------------------------

data_file_path = os.path.join("..","data")
csv_data_file = os.path.join(data_file_path, "reduced_repord_data.csv")

# %%
#----------------------------------------------------------------
# Import the procedures that download and transform the pdf file
# into a dataframe.
#----------------------------------------------------------------

module_path = os.path.abspath(os.path.join('..','src'))
print(module_path)
if module_path not in sys.path:
    sys.path.append(module_path)

from ETL import load_data_file
from ETL import calculate_daily_diffs
from ETL import init_logger


init_logger('/tmp', "etl-notebook.log",log_level=logging.DEBUG, std_out_log_level=logging.ERROR)
# Out:
# /home/giovanni/code-personal/python/CoronaVirus/src

# %%
print(csv_data_file)
df = load_data_file(csv_data_file)
(df.shape, df["REPORT DATE"].min(), df["REPORT DATE"].max(),df.dtypes)
# Out:
# ../data/reduced_repord_data.csv
# ((5145, 10),
#  '2020-05-01',
#  '2020-12-31',
#  REPORT DATE                     object
#  Regione                         object
#  Ricoverati con sintomi           int64
#  Terapia intensiva                int64
#  Totale attualmente positivi      int64
#  DECEDUTI                         int64
#  Isolamento domiciliare           int64
#  CASI TOTALI - A                  int64
#  Totale tamponi effettuati      float64
#  SCHEMA VERSION                  object
#  dtype: object)

# %%
df.head(3)
# Out:
#   REPORT DATE   Regione  Ricoverati con sintomi  Terapia intensiva  \
# 0  2020-05-01    Molise                      17                  1
# 1  2020-05-01    Trento                     146                 19
# 2  2020-05-01  Piemonte                    2503                181
#
#    Totale attualmente positivi DECEDUTI  Isolamento domiciliare  \
# 0                          190       21                     172
# 1                         1293      423                    1128
# 2                        15562     3097                   12878
#
#   CASI TOTALI - A Totale tamponi effettuati SCHEMA VERSION
# 0             300                      6463             v5
# 1            4132                     37838             v5
# 2           26684                    162568             v5

# %%
mask = df['Regione'] == 'Lombardia'
df.loc[mask,'delta 2'] = df_lombardia['CASI TOTALI - A'].diff(periods = 1)

df[mask].head(15)
# Out:
#     REPORT DATE    Regione  Ricoverati con sintomi  Terapia intensiva  \
# 10   2020-05-01  Lombardia                    6628                563
# 22   2020-05-02  Lombardia                    6529                545
# 57   2020-05-03  Lombardia                    6609                532
# 74   2020-05-04  Lombardia                    6414                532
# 99   2020-05-05  Lombardia                    6201                509
# 116  2020-05-06  Lombardia                    6079                480
# 135  2020-05-07  Lombardia                    5848                480
# 163  2020-05-08  Lombardia                    5702                400
# 183  2020-05-09  Lombardia                    5535                330
# 200  2020-05-10  Lombardia                    5428                348
# 225  2020-05-11  Lombardia                    5397                341
# 246  2020-05-12  Lombardia                    5222                322
# 261  2020-05-13  Lombardia                    5007                307
# 288  2020-05-14  Lombardia                    4818                297
# 309  2020-05-15  Lombardia                    4705                276
#
#      Totale attualmente positivi  DECEDUTI  Isolamento domiciliare  \
# 10                         36473     13860                   29282
# 22                         36667     14189                   29593
# 57                         36926     14231                   29785
# 74                         37307     14294                   30361
# 99                         37092     14389                   30382
# 116                        31753     14611                   25194
# 135                        32015     14745                   25687
# 163                        31983     14839                   25881
# 183                        30262     14924                   24397
# 200                        30190     14986                   24414
# 225                        30411     15054                   24673
# 246                        30675     15116                   25131
# 261                        30032     15185                   24718
# 288                        29956     15296                   24841
# 309                        27746     15411                   22765
#
#      CASI TOTALI - A  Totale tamponi effettuati SCHEMA VERSION  delta 2
# 10             76469                   390644.0             v5      NaN
# 22             77002                   403702.0             v5    533.0
# 57             77528                   410857.0             v5    526.0
# 74             78105                   418835.0             v5    577.0
# 99             78605                   425290.0             v5    500.0
# 116            79369                   439806.0             v5    764.0
# 135            80089                   455294.0             v5    720.0
# 163            80723                   466287.0             v5    634.0
# 183            81225                   477765.0             v5    502.0
# 200            81507                   485134.0             v5    282.0
# 225            81871                   492642.0             v5    364.0
# 246            82904                   513244.0             v5   1033.0
# 261            83298                   524163.0             v5    394.0
# 288            83820                   538243.0             v5    522.0
# 309            84119                   550405.0             v5    299.0

# %%
df.loc[mask, dest_col] = df.loc[mask, in_col].diff(periods = 1)
